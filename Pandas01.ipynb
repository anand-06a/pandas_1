# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#pandas series--one-dimensional labeled array.
marks=pd.Series([85,90,78,92,88])
print(marks)#index--0,1,2,3,4,values--85,90,78,92,88
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# dtype: int64

# %%
#custom index
marks=pd.Series([85,90,78],index=["Python","Sql","Pandas"])
print(marks)
# Out:
# Python    85
# Sql       90
# Pandas    78
# dtype: int64

# %%
#access
print(marks["Python"])
# Out:
# 85

# %%
#creating a dataframe--Adataframe is similar to an excel table.
data={"Name":["Anand","Rahul","Priya","kiran"],"Age":[20,23,21,24],"Marks":[85,90,78,92]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0  Anand   20     85
# 1  Rahul   23     90
# 2  Priya   21     78
# 3  kiran   24     92

# %%
#understanding DataFrame components.
#A dataframe contains-index,columns,values.
print(df.index)
print(df.columns)
print(df.values)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['Name', 'Age', 'Marks'], dtype='object')
# [['Anand' 20 85]
#  ['Rahul' 23 90]
#  ['Priya' 21 78]
#  ['kiran' 24 92]]

# %%
# # reading csv files--this is one of the most important pandas operations.
# df=pd.read_csv("students.csv")
# display-print(df)
# first 5 rows--df.head(5)
# last 5 rows --df.tail(5)
# first 10 rows--df.head(10)
# last 10 rows--df.head(10)

# %%
# #reading excel files.
# df=pd.read_excel("student.xlsx")
# specific sheet-
# df=pd.read_excel("student.xlsx",sheet_name=:Sheet1")

# %%
# #reading JSON
# df.read_json("students.json")

# %%
# #reading sql data.
# import pandas as pd
# import sqlite3
# connection=sqlite3.connect("company.db")
# df=pd.read_sql("SELECT*FROM employees",connection)
# print(df) #here this is very useful when combining sql+python+pandas.

# %%
# #inspecting data--after loading a dataset,the first thing you should do is understand it.
# head()--df.head()
# tail()--df.tail()
# shape--print(df.shape)--Ex-1000 rows c 8 columns

# %%
# #info()--very important for data analysis.
# #it tells--number of rows,columns,data types,non-null values,memory usage.
# df.info()

# %%
# #describe()--used for statistical summary.it provides(mean,count,standaed deviation,minimum,25%,50%,75%,maximum)
# df["salary"].describe()

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
#checking data types.
print(df.dtypes)
# Out:
# Name     object
# Age       int64
# Marks     int64
# dtype: object

# %%
#selecting a column
df["Name"]
#Multiple columns.
df[["Name","Age"]]
# Out:
#     Name  Age
# 0  Anand   20
# 1  Rahul   23
# 2  Priya   21
# 3  kiran   24

# %%
#selecting rows--using iloc(iloc uses numerical positions)
df.iloc[0]
#first 3 row
df.iloc[0:3]
# Out:
#     Name  Age  Marks
# 0  Anand   20     85
# 1  Rahul   23     90
# 2  Priya   21     78

# %%
#using loc.loc uses labels.
df.loc[0]
# Out:
# Name     Anand
# Age         20
# Marks       85
# Name: 0, dtype: object

# %%
#multiple rows.
df.loc[0:2]
# Out:
#     Name  Age  Marks
# 0  Anand   20     85
# 1  Rahul   23     90
# 2  Priya   21     78

# %%
#specific columns.
df.loc[0:2,["Name","Marks"]]
# Out:
#     Name  Marks
# 0  Anand     85
# 1  Rahul     90
# 2  Priya     78

# %%
# #difference b/w loc and iloc 
# loc-label based,df.loc[2],uses row /column labels
# iloc--position based,df.iloc[2,uses integer positions

# %%
#filtering data.
df=pd.DataFrame({"Name":["Anand","Rahul","Priya","kiran"],"Age":[22,25,21,30],"Salary":[30000,45000,28000,60000]})
#find people whose salary is greater than 40000.
result=df[df["Salary"]>40000]
print(result)
# Out:
#     Name  Age  Salary
# 1  Rahul   25   45000
# 3  kiran   30   60000

# %%
#multiple conditions,And ,or
df[(df["Age"]>22)&(df["Salary"]>40000)]
# Out:
#     Name  Age  Salary
# 1  Rahul   25   45000
# 3  kiran   30   60000

# %%
# #isin()--find employees from selected departments.
# df[df["department".isin(["IT","HR"])]]

# %%
#b/w(). this selects age from 20 to 25.
df[df["Age"].between(20,25)]
# Out:
#     Name  Age  Salary
# 0  Anand   22   30000
# 1  Rahul   25   45000
# 2  Priya   21   28000

# %%
#sorting data-Asending.
df.sort_values("Salary")
# Out:
#     Name  Age  Salary
# 2  Priya   21   28000
# 0  Anand   22   30000
# 1  Rahul   25   45000
# 3  kiran   30   60000

# %%
#Desending.
df.sort_values("Salary",ascending=False)
# Out:
#     Name  Age  Salary
# 3  kiran   30   60000
# 1  Rahul   25   45000
# 0  Anand   22   30000
# 2  Priya   21   28000

# %%
#multiple columns.
df.sort_values(["Name","Salary"],ascending=[True,False])
# Out:
#     Name  Age  Salary
# 0  Anand   22   30000
# 2  Priya   21   28000
# 1  Rahul   25   45000
# 3  kiran   30   60000

# %%
# # #isin()
# df=df[df["Name"].isin(["Priya","kiran"])]

# %%
#filtering data.
df=pd.DataFrame({"Name":["Anand","Rahul","Priya","kiran"],"Age":[22,25,21,30],"Salary":[30000,45000,28000,60000]})
#find people whose salary is greater than 40000.
result=df[df["Salary"]>40000]
print(result)
# Out:
#     Name  Age  Salary
# 1  Rahul   25   45000
# 3  kiran   30   60000

# %%
#Adding a New Column.
import pandas as pd
df["Bonus"]=df["Salary"]*0.10

# %%
#multiple conditions
df[
    (df["Age"] > 22) &
    (df["Salary"] > 40000)
]
# Out:
#     Name  Age  Salary   Bonus
# 1  Rahul   25   45000  4500.0
# 3  kiran   30   60000  6000.0

# %%
df[df["Age"].between(20, 25)]
# Out:
#     Name  Age  Salary   Bonus
# 0  Anand   22   30000  3000.0
# 1  Rahul   25   45000  4500.0
# 2  Priya   21   28000  2800.0

# %%
df.sort_values("Salary")
# Out:
#     Name  Age  Salary   Bonus
# 2  Priya   21   28000  2800.0
# 0  Anand   22   30000  3000.0
# 1  Rahul   25   45000  4500.0
# 3  kiran   30   60000  6000.0

# %%
#multiple columns.
df.sort_values(
    ["Name", "Salary"],
    ascending=[True, False]
)
# Out:
#     Name  Age  Salary   Bonus
# 0  Anand   22   30000  3000.0
# 2  Priya   21   28000  2800.0
# 1  Rahul   25   45000  4500.0
# 3  kiran   30   60000  6000.0

# %%
#Adding a New Column.
df["Bonus"]=df["Salary"]*0.10

# %%
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Anand   22   30000  3000.0
# 1  Rahul   25   45000  4500.0
# 2  Priya   21   28000  2800.0
# 3  kiran   30   60000  6000.0

# %%
#updating a column.
df["Salary"] = df["Salary"] + 5000
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Anand   22   40000  3000.0
# 1  Rahul   25   55000  4500.0
# 2  Priya   21   38000  2800.0
# 3  kiran   30   70000  6000.0

# %%
#renaming columns.
df.rename(columns={"Salary":"Annual Salary"},inplace=True)
df
# Out:
#     Name  Age  Annual Salary   Bonus
# 0  Anand   22          40000  3000.0
# 1  Rahul   25          55000  4500.0
# 2  Priya   21          38000  2800.0
# 3  kiran   30          70000  6000.0

# %%
df.rename(columns={"Salary":"Annual Salary"})
df
# Out:
#     Name  Age  Annual Salary   Bonus
# 0  Anand   22          40000  3000.0
# 1  Rahul   25          55000  4500.0
# 2  Priya   21          38000  2800.0
# 3  kiran   30          70000  6000.0

# %%
#multiple column.
df.rename(
    columns={
        "Name": "Employee_Name",
        "Age": "Employee_Age"
    },
    inplace=True
)

# %%
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#Droping Columns.
df.drop("Employee_Age",axis=1)
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
df.drop(0)
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
df.drop([0,2])
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 1         Rahul            25          55000  4500.0
# 3         kiran            30          70000  6000.0

# %%
#missing values.
df.isnull()
# Out:
#    Employee_Name  Employee_Age  Annual Salary  Bonus
# 0          False         False          False  False
# 1          False         False          False  False
# 2          False         False          False  False
# 3          False         False          False  False

# %%
#count.
df.isnull().sum()
# Out:
# Employee_Name    0
# Employee_Age     0
# Annual Salary    0
# Bonus            0
# dtype: int64

# %%
#alternative.
df.isna().sum()
# Out:
# Employee_Name    0
# Employee_Age     0
# Annual Salary    0
# Bonus            0
# dtype: int64

# %%
#Removing Missing Values.
df.dropna()
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#remove rows containing null values.
df.dropna(inplace=True)
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#Filling Missing Values.
df["Employee_Age"].fillna(25)
# Out:
# 0    22
# 1    25
# 2    21
# 3    30
# Name: Employee_Age, dtype: int64

# %%
#using mean Values.
df["Employee_Name"].fillna(df["Employee_Age"].mean(),inplace=True)
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
df["Annual Salary"].fillna(df["Annual Salary"].mean(),inplace=True)
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#forward Fill.--it uses the previous value.
df.fillna(method="ffill")
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#backward Fill.--it uses the next available value.
df.fillna(method="bfill")
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#Duplicate Data.
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 1         Rahul            25          55000  4500.0
# 2         Priya            21          38000  2800.0
# 3         kiran            30          70000  6000.0

# %%
#unique values.
df["Employee_Name"].unique()
# Out:
# array(['Anand', 'Rahul', 'Priya', 'kiran'], dtype=object)

# %%
#Number of unique values.
df["Employee_Name"].nunique()
# Out:
# 4

# %%
#Frequency of Values.--very useful for categorical analysis.
df["Employee_Name"].value_counts()
# Out:
# Anand    1
# Rahul    1
# Priya    1
# kiran    1
# Name: Employee_Name, dtype: int64

# %%
#String Operations.
#convert names to uppercase.
df["Employee_Name"].str.upper()
# Out:
# 0    ANAND
# 1    RAHUL
# 2    PRIYA
# 3    KIRAN
# Name: Employee_Name, dtype: object

# %%
#lower case.
df["Employee_Name"].str.lower()
# Out:
# 0    anand
# 1    rahul
# 2    priya
# 3    kiran
# Name: Employee_Name, dtype: object

# %%
#length.
df["Employee_Name"].str.len()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# Name: Employee_Name, dtype: int64

# %%
#contains.
df[df["Employee_Name"].str.contains("an")]
# Out:
#   Employee_Name  Employee_Age  Annual Salary   Bonus
# 0         Anand            22          40000  3000.0
# 3         kiran            30          70000  6000.0

# %%
#replace.
df["Employee_Name"].str.replace("Anand", "ANAND")
# Out:
# 0    ANAND
# 1    Rahul
# 2    Priya
# 3    kiran
# Name: Employee_Name, dtype: object

# %%
#apply()--apply a function to a column.
def Annual_salary_category(Annual_salary):
    if Annual_salary >= 50000:
        return "High"
    else:
        return "Low"

df["Category"] = df["Annual_Salary"].apply(
    Annual salary_category
)
# Out:
#   File "C:\Users\anand\AppData\Local\Temp\ipykernel_29668\145852466.py", line 9
#     Annual salary_category
#                          ^
# SyntaxError: invalid syntax
